# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
data = pd.read_excel("Movie_dataset.xlsx")
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
# ...

# %%
data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga -1988.0      NaN         Action     4.6    11
# 15505                Zulmi -1999.0  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj -2005.0      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari -1988.0      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam -1998.0  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
data['Actor 1'].unique()
# Out:
# array(['Manmauji', 'Rasika Dugal', 'Sayani Gupta', ..., 'Meghan Jadhav',
#        'Roohi Berde', 'Sangeeta Tiwari'], dtype=object)

# %%
data['Actor 2'].unique()
# Out:
# array(['Birbal', 'Vivek Ghamande', 'Plabita Borthakur', ...,
#        'Devan Sanjeev', 'Prince Daniel', 'Sarah Jane Dias'], dtype=object)

# %%
data['Actor 3'].unique()
# Out:
# array(['Rajendra Bhatia', 'Arvind Jangid', 'Roy Angana', ...,
#        'Shatakshi Gupta', 'Valerie Agha', 'Suparna Anand'], dtype=object)

# %%
data['Director'].unique()
# Out:
# array(['J.S. Randhawa', 'Gaurav Bakshi', 'Soumyajit Majumdar', ...,
#        'Mozez Singh', 'Ved Prakash', 'Kiran Thej'], dtype=object)

# %%
data['Votes'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        NaN
# 1          8
# 2        NaN
# 3         35
# 4        NaN
#         ...
# 15504     11
# 15505    655
# 15506    NaN
# 15507    NaN
# 15508     20
# Name: Votes, Length: 15509, dtype: object>

# %%
data['Rating'].unique()
# Out:
# array([ nan,  7. ,  4.4,  4.7,  7.4,  5.6,  4. ,  6.2,  5.9,  6.5,  5.7,
#         6.3,  7.2,  6.6,  7.3,  7.1,  6.9,  3.5,  5. ,  4.5,  6.4,  4.1,
#         4.8,  8.1,  5.5,  6.8,  6.1,  7.7,  5.1,  7.6,  3.1,  3.3,  7.8,
#         8.4,  5.2,  4.3,  5.8,  4.6,  7.5,  6.7,  3.6,  3.9,  5.4,  4.2,
#         5.3,  3.4,  3. ,  8. ,  6. ,  3.8,  7.9,  2.7,  4.9,  2.4,  3.7,
#         3.2,  2.5,  2.8,  2.6,  2.9,  8.2,  8.7,  8.3,  9.3,  8.8,  2.1,
#         2.3,  8.5,  8.6,  9. ,  9.6,  1.7,  9.1,  2. ,  1.4,  8.9,  1.9,
#         9.4,  9.7,  1.8,  9.2,  1.6, 10. ,  2.2,  1.1])

# %%
data['Genre'].unique()
# Out:
# array(['Drama', 'Drama, Musical', 'Comedy, Romance',
#        'Comedy, Drama, Musical', 'Drama, Romance, War', 'Documentary',
#        'Horror, Mystery, Thriller', 'Action, Crime, Thriller', 'Horror',
#        'Horror, Romance, Thriller', 'Comedy, Drama, Romance', 'Thriller',
#        'Comedy, Drama', nan, 'Comedy, Drama, Fantasy',
#        'Comedy, Drama, Family', 'Crime, Drama, Mystery',
#        'Horror, Thriller', 'Biography', 'Comedy, Horror', 'Action',
#        'Drama, Horror, Mystery', 'Comedy', 'Action, Thriller',
#        'Drama, History', 'Drama, History, Sport',
#        'Horror, Mystery, Romance', 'Horror, Mystery',
#        'Drama, Horror, Romance', 'Action, Drama, History',
#        'Action, Drama, War', 'Comedy, Family',
#        'Adventure, Horror, Mystery', 'Action, Sci-Fi',
#        'Crime, Mystery, Thriller', 'War', 'Sport',
#        'Biography, Drama, History', 'Horror, Romance', 'Crime, Drama',
# ...

# %%
data['Year'].unique()
# Out:
# array([   nan, -2019., -2021., -2010., -1997., -2005., -2008., -2012.,
#        -2014., -2004., -2016., -1991., -1990., -2018., -1987., -1948.,
#        -1958., -2017., -2020., -2009., -2002., -1993., -1946., -1994.,
#        -2007., -2013., -2003., -1998., -1979., -1951., -1956., -1974.,
#        -2015., -2006., -1981., -1985., -2011., -2001., -1967., -1988.,
#        -1995., -1959., -1996., -1970., -1976., -2000., -1999., -1973.,
#        -1968., -1943., -1953., -1986., -1983., -1989., -1982., -1977.,
#        -1957., -1950., -1992., -1969., -1975., -1947., -1972., -1971.,
#        -1935., -1978., -1960., -1944., -1963., -1940., -1984., -1934.,
#        -1955., -1936., -1980., -1966., -1949., -1962., -1964., -1952.,
#        -1933., -1942., -1939., -1954., -1945., -1961., -1965., -1938.,
#        -1941., -1931., -1937., -2022., -1932., -1923., -1915., -1928.,
#        -1922., -1917., -1913., -1930., -1926., -1914., -1924.])

# %%
data['Duration'].unique()
# Out:
# array([nan, '109 min', '90 min', '110 min', '105 min', '147 min',
#        '142 min', '59 min', '82 min', '116 min', '96 min', '120 min',
#        '161 min', '166 min', '102 min', '87 min', '132 min', '66 min',
#        '146 min', '112 min', '168 min', '158 min', '126 min', '94 min',
#        '138 min', '124 min', '144 min', '157 min', '136 min', '107 min',
#        '113 min', '80 min', '122 min', '149 min', '148 min', '130 min',
#        '121 min', '188 min', '115 min', '103 min', '114 min', '170 min',
#        '100 min', '99 min', '140 min', '128 min', '93 min', '125 min',
#        '145 min', '75 min', '111 min', '134 min', '85 min', '104 min',
#        '92 min', '137 min', '127 min', '150 min', '119 min', '135 min',
#        '86 min', '76 min', '70 min', '72 min', '151 min', '95 min',
#        '52 min', '89 min', '143 min', '177 min', '117 min', '123 min',
#        '154 min', '88 min', '175 min', '153 min', '78 min', '139 min',
# ...

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
data.replace(['NaN', 'N/A', 'NA', 'n/a', 'n.a.', 'N#A', 'n#a', '?'], 'other', inplace=True)
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
# ...

# %%
data.describe()
# Out:
#                Year       Rating
# count  14981.000000  7919.000000
# mean   -1987.012215     5.841621
# std       25.416689     1.381777
# min    -2022.000000     1.100000
# 25%    -2009.000000     4.900000
# 50%    -1991.000000     6.000000
# 75%    -1968.000000     6.800000
# max    -1913.000000    10.000000

# %%
numerical_vars = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_vars = data.select_dtypes(include=['object']).columns.tolist()                           
print('Numerical variables:', numerical_vars)
print('Categorical variables:', categorical_vars)
# Out:
# Numerical variables: ['Year', 'Rating']
# Categorical variables: ['Name', 'Duration', 'Genre', 'Votes', 'Director', 'Actor 1', 'Actor 2', 'Actor 3']

# %%
# Count the number of categorical and numerical variables
categorical_count = data.select_dtypes(include='object').shape[1]
numerical_count = data.select_dtypes(exclude='object').shape[1]

print(f"Number of categorical variables: {categorical_count}")
print(f"Number of numerical variables: {numerical_count}")
# Out:
# Number of categorical variables: 8
# Number of numerical variables: 2

# %%
print(data.select_dtypes(include=['object']).nunique())
# Out:
# Name        13838
# Duration      182
# Genre         485
# Votes        2034
# Director     5938
# Actor 1      4718
# Actor 2      4891
# Actor 3      4820
# dtype: int64

# %%
missing_df =  data.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
missing_df["% of Missing Values"] = round((missing_df["Total No. of Missing Values"]/len( data))*100,2)
missing_df
# Out:
#           Total No. of Missing Values  % of Missing Values
# Name                                0                 0.00
# Year                              528                 3.40
# Duration                         8269                53.32
# Genre                            1877                12.10
# Rating                           7590                48.94
# Votes                            7589                48.93
# Director                          525                 3.39
# Actor 1                          1617                10.43
# Actor 2                          2384                15.37
# Actor 3                          3144                20.27

# %%
# Calculate the percentage of missing values for each column
missing_values_percentage = data.isnull().mean() * 100

# Now you can sort and visualize the missing values
missing_values_percentage_sorted = missing_values_percentage.sort_values()

# Visualization code
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x=missing_values_percentage_sorted, y=missing_values_percentage_sorted.index)
plt.title('Percentage of Missing Values in Each Column (Ascending Order)')
plt.xlabel('Percentage of Missing Values')
plt.ylabel('Columns')
plt.show()

# %%
sns.heatmap(data.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# Handling missing values
# Imputing missing values with the mean for continuous variables and mode for categorical variables
for col in data.columns:
    if data[col].dtype == 'object':
        data[col].fillna(data[col].mode()[0], inplace=True)
    else:
        data[col].fillna(data[col].mean(), inplace=True)

# Checking for missing values before imputation
missing_values = data.isnull().sum()

# %%
# Rechecking for missing values after imputation
missing_values_after = data.isnull().sum()

(missing_values, missing_values_after)
# Out:
# (Name        0
#  Year        0
#  Duration    0
#  Genre       0
#  Rating      0
#  Votes       0
#  Director    0
#  Actor 1     0
#  Actor 2     0
#  Actor 3     0
#  dtype: int64,
#  Name        0
#  Year        0
#  Duration    0
#  Genre       0
#  Rating      0
#  Votes       0
#  Director    0
#  Actor 1     0
#  Actor 2     0
#  Actor 3     0
#  dtype: int64)

# %%
missing_df =  data.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
missing_df["% of Missing Values"] = round((missing_df["Total No. of Missing Values"]/len( data))*100,2)
missing_df
# Out:
#           Total No. of Missing Values  % of Missing Values
# Name                                0                  0.0
# Year                                0                  0.0
# Duration                            0                  0.0
# Genre                               0                  0.0
# Rating                              0                  0.0
# Votes                               0                  0.0
# Director                            0                  0.0
# Actor 1                             0                  0.0
# Actor 2                             0                  0.0
# Actor 3                             0                  0.0

# %%
data[data.duplicated(keep = False)]
# Out:
#                             Name         Year Duration     Genre    Rating  \
# 1249   Arab Ka Sona - Abu Kaalia -1979.000000  120 min    Action  5.841621
# 1250   Arab Ka Sona - Abu Kaalia -1979.000000  120 min    Action  5.841621
# 1768                     Balidan -1992.000000  120 min     Drama  5.841621
# 1769                     Balidan -1992.000000  120 min     Drama  5.841621
# 4722     First Time - Pehli Baar -2009.000000  120 min     Drama  5.841621
# 4723     First Time - Pehli Baar -2009.000000  120 min     Drama  5.841621
# 9712                     Musafir -1987.012215  120 min  Thriller  5.841621
# 9713                     Musafir -1987.012215  120 min  Thriller  5.841621
# 13068                    Shivani -2019.000000  120 min     Crime  5.841621
# 13069                    Shivani -2019.000000  120 min     Crime  5.841621
# 13307          Slumdog Karodpati -2019.000000  118 min  Thriller  5.841621
# ...

# %%
data.duplicated().sum()
# Out:
# 6

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (15503, 10)

# %%
# Get the list of categorical columns
cat_cols = data.select_dtypes(include='object').columns.tolist()

# %%
# Ensure all categorical columns are converted to strings
data[cat_cols] = data[cat_cols].astype(str)

# Melt the DataFrame and count unique values
melted_df = data[cat_cols].melt(var_name='column', value_name='value')
count_df = melted_df.groupby(['column', 'value']).size().reset_index(name='count')

# Sort the DataFrame
sorted_count_df = count_df.sort_values(by=['column', 'count'])

# Display the sorted DataFrame
sorted_count_df
# Out:
#         column        value  count
# 0      Actor 1     A. Muthu      1
# 1      Actor 1   A. Nairang      1
# 3      Actor 1   A.K. Misra      1
# 4      Actor 1  A.N. Ansari      1
# 6      Actor 1       A.R.S.      1
# ...        ...          ...    ...
# 34873    Votes           10    175
# 36457    Votes            6    213
# 36822    Votes            9    221
# 36594    Votes            7    224
# 36721    Votes            8   7810
#
# [36906 rows x 3 columns]

# %%
display(data[cat_cols].describe())

# Display counts of unique values for each categorical column
display(count_df)
# Out:
#           Name Duration  Genre  Votes      Director      Actor 1 Actor 2  \
# count    15503    15503  15503  15503         15503        15503   15503
# unique   13838      182    485   2034          5938         4718    4891
# top     Anjaam  120 min  Drama      8  Jayant Desai  Ashok Kumar   Rekha
# freq         7     8504   4655   7810           582         1773    2464
#
#        Actor 3
# count    15503
# unique    4820
# top       Pran
# freq      3231
#         column        value  count
# 0      Actor 1     A. Muthu      1
# 1      Actor 1   A. Nairang      1
# 2      Actor 1  A.K. Hangal      3
# 3      Actor 1   A.K. Misra      1
# 4      Actor 1  A.N. Ansari      1
# ...        ...          ...    ...
# 36901    Votes         9909      1
# 36902    Votes          996      1
# 36903    Votes          998      1
# 36904    Votes          999      1
# 36905    Votes         9990      1
#
# [36906 rows x 3 columns]

# %%
data.describe(include='O').T
# Out:
#           count unique           top  freq
# Name      15503  13838        Anjaam     7
# Duration  15503    182       120 min  8504
# Genre     15503    485         Drama  4655
# Votes     15503   2034             8  7810
# Director  15503   5938  Jayant Desai   582
# Actor 1   15503   4718   Ashok Kumar  1773
# Actor 2   15503   4891         Rekha  2464
# Actor 3   15503   4820          Pran  3231

# %%
data.nunique().sort_values()
# Out:
# Rating         85
# Year          103
# Duration      182
# Genre         485
# Votes        2034
# Actor 1      4718
# Actor 3      4820
# Actor 2      4891
# Director     5938
# Name        13838
# dtype: int64

# %%
data1= pd.get_dummies(data, columns=['Duration', 'Director','Votes'], drop_first=True)
data1
# Out:
#                                      Name         Year            Genre  \
# 0                                         -1987.012215            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.000000            Drama
# 2                             #Homecoming -2021.000000   Drama, Musical
# 3                                 #Yaaram -2019.000000  Comedy, Romance
# 4                       ...And Once Again -2010.000000            Drama
# ...                                   ...          ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.000000           Action
# 15505                               Zulmi -1999.000000    Action, Drama
# 15506                           Zulmi Raj -2005.000000           Action
# 15507                       Zulmi Shikari -1988.000000           Action
# 15508                        Zulm-O-Sitam -1998.000000    Action, Drama
#
#          Rating           Actor 1             Actor 2          Actor 3  \
# ...

# %%
data2= pd.get_dummies(data, columns=['Actor 1', 'Actor 3','Actor 2'], drop_first=True)
data2
# Out:
#                                      Name         Year Duration  \
# 0                                         -1987.012215  120 min
# 1      #Gadhvi (He thought he was Gandhi) -2019.000000  109 min
# 2                             #Homecoming -2021.000000   90 min
# 3                                 #Yaaram -2019.000000  110 min
# 4                       ...And Once Again -2010.000000  105 min
# ...                                   ...          ...      ...
# 15504                 Zulm Ko Jala Doonga -1988.000000  120 min
# 15505                               Zulmi -1999.000000  129 min
# 15506                           Zulmi Raj -2005.000000  120 min
# 15507                       Zulmi Shikari -1988.000000  120 min
# 15508                        Zulm-O-Sitam -1998.000000  130 min
#
#                  Genre    Rating Votes            Director  \
# 0                Drama  5.841621     8       J.S. Randhawa
# 1                Drama  7.000000     8       Gaurav Bakshi
# ...

# %%
data3= pd.get_dummies(data, columns=['Genre', 'Name'], drop_first=True)
data3
# Out:
#               Year Duration    Rating Votes            Director  \
# 0     -1987.012215  120 min  5.841621     8       J.S. Randhawa
# 1     -2019.000000  109 min  7.000000     8       Gaurav Bakshi
# 2     -2021.000000   90 min  5.841621     8  Soumyajit Majumdar
# 3     -2019.000000  110 min  4.400000    35          Ovais Khan
# 4     -2010.000000  105 min  5.841621     8        Amol Palekar
# ...            ...      ...       ...   ...                 ...
# 15504 -1988.000000  120 min  4.600000    11       Mahendra Shah
# 15505 -1999.000000  129 min  4.500000   655          Kuku Kohli
# 15506 -2005.000000  120 min  5.841621     8          Kiran Thej
# 15507 -1988.000000  120 min  5.841621     8        Jayant Desai
# 15508 -1998.000000  130 min  6.200000    20        K.C. Bokadia
#
#                 Actor 1             Actor 2          Actor 3  \
# 0              Manmauji              Birbal  Rajendra Bhatia
# 1          Rasika Dugal      Vivek Ghamande    Arvind Jangid
# ...

# %%
# Plot the boxplot with rotated text labels
data.plot(kind='box', rot=45,color='green')

# Show the plot
plt.show()

# %%
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns

# Plotting boxplots for each numerical feature to identify outliers
for column in numeric_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=data[column],palette='rainbow')
    plt.title(f'Boxplot of {column}')
    plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_28744\3045913372.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data[column],palette='rainbow')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_28744\3045913372.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data[column],palette='rainbow')

# %%
# Correlation matrix

# Select only the numeric columns from the DataFrame
numeric_columns = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='rainbow', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # Data Visualization

# %%
# Explore categorical features
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Actor 2', data=data,order=data['Actor 2'].value_counts().index[:25])
ax.set_title('Count Plot for Actor 2')
ax.set_xlabel('Count')
ax.set_ylabel('Actor 2')
plt.xticks(rotation=45)
plt.show()

# %%
# Explore categorical features
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Actor 1', data=data,order=data['Actor 1'].value_counts().index[:25])
ax.set_title('Count Plot for Actor 1')
ax.set_xlabel('Count')
ax.set_ylabel('Actor 1')
plt.xticks(rotation=45)
plt.show()

# %%
# Explore categorical features
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Duration', data=data,order=data['Duration'].value_counts().index[:25])
ax.set_title('Count Plot for Duration')
ax.set_xlabel('Count')
ax.set_ylabel('Duration')
plt.xticks(rotation=45)
plt.show()

# %%
# Explore categorical features
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Genre', data=data,order=data['Genre'].value_counts().index[:25])
ax.set_title('Count Plot for Genre')
ax.set_xlabel('Count')
ax.set_ylabel('Genre')
plt.xticks(rotation=45)
plt.show()

# %%
# Explore categorical features
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Director', data=data,order=data['Director'].value_counts().index[:25])
ax.set_title('Count Plot for Director')
ax.set_xlabel('Count')
ax.set_ylabel('Director')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14, 8))

# Create a box plot
ax = sns.boxplot(x='Director', y='Rating', data=data, order=data['Director'].value_counts().index[:30])
ax.set_title('Rating Distribution by Director')
ax.set_xlabel('Director')
ax.set_ylabel('Rating')
plt.xticks(rotation=90)

# Show plot
plt.show()

# %%
avg_rating = data.groupby('Director')['Rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(14, 8))

# Create a bar plot
ax = sns.barplot(x=avg_rating.index, y=avg_rating.values, palette='viridis')
ax.set_title('Average Rating Distribution by Director')
ax.set_xlabel('Director')
ax.set_ylabel('Average Rating')
plt.xticks(rotation=90)

# Show plot
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_28744\519941708.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=avg_rating.index, y=avg_rating.values, palette='viridis')

# %%
column_name = 'Genre'  # Replace with your column name
top_10_categories = data[column_name].value_counts().nlargest(10)

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(top_10_categories, labels=top_10_categories.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(top_10_categories)))

# Add a title
plt.title(f'Top 10 {column_name} Distribution')

# Show plot
plt.show()

# %%
column_name = 'Duration'  # Replace with your column name
top_10_categories = data[column_name].value_counts().nlargest(10)

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(top_10_categories, labels=top_10_categories.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(top_10_categories)))

# Add a title
plt.title(f'Top 10 {column_name} Distribution')

# Show plot
plt.show()

# %%
column_name = 'Rating'  # Replace with your column name
top_10_categories = data[column_name].value_counts().nlargest(10)

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(top_10_categories, labels=top_10_categories.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(top_10_categories)))

# Add a title
plt.title(f'Top 10 {column_name} Distribution')

# Show plot
plt.show()

# %%
column_name = 'Votes'  # Replace with your column name
top_10_categories = data[column_name].value_counts().nlargest(10)

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(top_10_categories, labels=top_10_categories.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(top_10_categories)))

# Add a title
plt.title(f'Top 10 {column_name} Distribution')

# Show plot
plt.show()

# %%
top_10_directors = data['Director'].value_counts().nlargest(10)
plt.figure(figsize=(10, 8))
plt.pie(top_10_directors, labels=top_10_directors.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(top_10_directors)))
plt.title('Top 10 Directors by Number of Movies')
plt.show()

# %%
top_10_Actors = data['Actor 1'].value_counts().nlargest(10)
plt.figure(figsize=(10, 8))
plt.pie(top_10_Actors, labels=top_10_Actors.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(top_10_directors)))
plt.title('Top 10 Actors by Number of Movies')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(y='Genre', data=data, order=data['Genre'].value_counts().index[:40])
plt.title('Genre Distribution')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.histplot(data['Rating'], bins=20, kde=True)
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(x='Votes', y='Rating', data=data)
plt.title('Votes vs Rating')
plt.xlabel('Votes')
plt.ylabel('Rating')
plt.show()

# %%
top_10_genres = data['Genre'].value_counts().nlargest(10).index

# Filter the dataset to include only the top 10 genres
filtered_df = data[data['Genre'].isin(top_10_genres)]

# Create the box plot
plt.figure(figsize=(14, 8))
sns.boxplot(x='Genre', y='Rating', data=filtered_df, order=top_10_genres)
plt.title('Rating Distribution by Top 10 Genres')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(y='Director', data=data, order=data['Director'].value_counts().nlargest(10).index)
plt.title('Top 10 Directors by Number of Movies')
plt.xlabel('Count')
plt.ylabel('Director')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual DataFrame)
# df = ...

# Function to remove outliers using the IQR method
def remove_outliers_iqr(data):
    # Select only numeric columns
    numeric_df = data.select_dtypes(include=['int64', 'float64'])
    
    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = numeric_df.quantile(0.25)
    Q3 = numeric_df.quantile(0.75)
    
    # Interquartile range (IQR)
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds for outlier detection
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify outliers
    outliers = ((numeric_df < lower_bound) | (numeric_df > upper_bound)).any(axis=1)
    
    # Count the number of outliers removed
    num_outliers_removed = outliers.sum()
    
    # Filter DataFrame based on rows without outliers
    df_no_outliers = data[~outliers]
    
    return df_no_outliers, num_outliers_removed

# Remove outliers using IQR method and get the number of outliers removed
df_no_outliers, num_outliers_removed = remove_outliers_iqr(data)

print("Number of outliers removed:", num_outliers_removed)

# Function to plot boxplots before and after removing outliers
def plot_boxplots_before_after(df_before, df_after):
    # Set up the figure
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
    
    # Boxplot before removing outliers (blue color)
    sns.boxplot(data=df_before, ax=axes[0], color='blue')
    axes[0].set_title('Before Removing Outliers')
    
    # Boxplot after removing outliers (green color)
    sns.boxplot(data=df_after, ax=axes[1], color='green')
    axes[1].set_title('After Removing Outliers')
    
    # Adjust layout
    plt.tight_layout()
    plt.show()

# Plot boxplots before and after outlier removal
plot_boxplots_before_after(data, df_no_outliers)
print("Number of outliers removed:", num_outliers_removed)
# Out:
# Number of outliers removed: 6632
# Number of outliers removed: 6632

# %% [markdown]
# # Machine Learning Models

# %%
catcol = []
numcol = []

for col in data.columns:
    if data[col].dtype == 'object':
        catcol.append(col)
    else:
        numcol.append(col)

# %%
print("Categorical Columns:",catcol)
print("Numerical Columns:", numcol)
# Out:
# Categorical Columns: ['Name', 'Duration', 'Genre', 'Votes', 'Director', 'Actor 1', 'Actor 2', 'Actor 3']
# Numerical Columns: ['Year', 'Rating']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for col in catcol:
    data[col] = encoder.fit_transform(data[col])

# %%
data.head()
# Out:
#    Name         Year  Duration  Genre    Rating  Votes  Director  Actor 1  \
# 0     0 -1987.012215        20    299  5.841621   1849      1926     2250
# 1     1 -2019.000000         9    299  7.000000   1849      1548     3280
# 2     2 -2021.000000       172    351  5.841621   1849      5123     3713
# 3     3 -2019.000000        10    228  4.400000   1108      3319     2917
# 4     7 -2010.000000         5    299  5.841621   1849       385     3112
#
#    Actor 2  Actor 3
# 0      800     3108
# 1     4790      527
# 2     2866     3450
# 3     1504     4020
# 4     3462      405

# %%
from sklearn.preprocessing import MinMaxScaler

scale = MinMaxScaler()

for col in numcol:
    data[[col]] = scale.fit_transform(data[[col]])

# %%
import os
import random
from sklearn import model_selection as sk_model_selection
from sklearn import preprocessing as sk_preprocessing
from sklearn import linear_model as sk_linear_model
from sklearn import svm as sk_svm
from sklearn import tree as sk_tree
from sklearn import ensemble as sk_ensemble
from sklearn import neighbors as sk_neighbors
from sklearn import metrics as sk_metrics

# %%
X = data.drop('Rating',axis=1)
y = data['Rating']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np

# Assuming X contains your features and y contains your continuous target (e.g., movie ratings)
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the regressor
rf_regressor.fit(X_train, y_train)

# Predictions on the test set
y_pred = rf_regressor.predict(X_test)

# Evaluate the regressor
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 0.01
# Root Mean Squared Error: 0.10
# R-squared: 0.19

# %% [markdown]
# * MSE: Indicates the average squared difference between predicted and actual ratings. Lower values are desirable.
# * RMSE: Provides a measure of the average magnitude of errors in the same units as the target variable. Lower values indicate better predictive accuracy.
# * R²: Measures how well the model fits the data. Values closer to 1 indicate a better fit, with higher explained variance by the model.

# %% [markdown]
# In our case, while the MSE and RMSE are quite low (indicating small prediction errors), the R² value of 0.19 suggests that the model explains only a modest proportion of the variance in movie ratings based on the selected features. Improving the R² could involve adding more relevant features, refining model parameters through hyperparameter tuning, or considering different modeling approaches to better capture the complexity of the relationship between features and ratings.

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Assuming X contains your features and y contains your continuous target (e.g., movie ratings)
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Gradient Boosting Regressor
gb_regressor = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Train the regressor
gb_regressor.fit(X_train, y_train)

# Predictions on the test set
y_pred = gb_regressor.predict(X_test)

# Evaluate the regressor
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 0.01
# Root Mean Squared Error: 0.10
# R-squared: 0.20

# %% [markdown]
# MSE of 0.01 and RMSE of 0.10 suggest that your model's predictions are quite close to the actual ratings on average.
# R² of 0.20 indicates that 20% of the variance in movie ratings can be explained by the features used in your Gradient Boosting Regressor model.

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Assuming X contains your features and y contains your continuous target (e.g., movie ratings)
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features (important for SVMs)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize the Support Vector Regressor
svm_regressor = SVR(kernel='rbf')

# Train the regressor
svm_regressor.fit(X_train_scaled, y_train)

# Predictions on the test set
y_pred_svm = svm_regressor.predict(X_test_scaled)

# Evaluate the regressor
mse_svm = mean_squared_error(y_test, y_pred_svm)
rmse_svm = np.sqrt(mse_svm)
r2_svm = r2_score(y_test, y_pred_svm)

print('Support Vector Machine Regressor:')
print(f'Mean Squared Error: {mse_svm:.2f}')
print(f'Root Mean Squared Error: {rmse_svm:.2f}')
print(f'R-squared: {r2_svm:.2f}')
# Out:
# Support Vector Machine Regressor:
# Mean Squared Error: 0.01
# Root Mean Squared Error: 0.11
# R-squared: 0.03

# %% [markdown]
# MSE and RMSE are comparable to the previous models, indicating similar predictive accuracy.
# R-squared is notably lower at 0.03, suggesting that only 3% of the variance in the ratings can be explained by the features used in the SVR model. This indicates that the SVR model might not be capturing the underlying relationships as effectively as the models in the first two sets.

# %% [markdown]
# Based on the provided evaluation metrics for the different regression models, let's classify the best performing model and discuss the reasons behind the classification.
#
# ### Models Evaluated:
#
# 1. **Model 1 (Random Forest or Gradient Boosting Regressor)**:
#    - **Mean Squared Error (MSE)**: 0.01
#    - **Root Mean Squared Error (RMSE)**: 0.10
#    - **R-squared (R²)**: 0.20
#
# 2. **Model 2 (Random Forest or Gradient Boosting Regressor)**:
#    - **Mean Squared Error (MSE)**: 0.01
#    - **Root Mean Squared Error (RMSE)**: 0.10
#    - **R-squared (R²)**: 0.19
#
# 3. **Support Vector Machine Regressor (SVR)**:
#    - **Mean Squared Error (MSE)**: 0.01
#    - **Root Mean Squared Error (RMSE)**: 0.11
#    - **R-squared (R²)**: 0.03
#
# ### Analysis and Classification:
#
# Based on the provided metrics, **Model 1** emerges as the best performing model. Here are the reasons for this classification:
#
# - **Lowest MSE and RMSE**: Both Model 1 and Model 2 have the same MSE and RMSE, which are lower than those of the SVR model. This indicates that Model 1 and Model 2 are making predictions that are closer to the actual ratings on average.
#
# - **Highest R-squared (R²)**: Model 1 has the highest R² among the evaluated models, with a value of 0.20. This indicates that 20% of the variance in the movie ratings can be explained by the features included in the model. A higher R² suggests that Model 1 provides a better fit to the data compared to the other models.
#
# - **Consistency Across Metrics**: Model 1 shows consistency across all metrics (MSE, RMSE, and R²), indicating robust performance in predicting movie ratings.
#
# - **Model Interpretability**: Random Forest and Gradient Boosting models (likely candidates for Model 1 and Model 2) also provide insights into feature importance, which can be crucial for understanding the factors driving movie ratings.
#
# ### Conclusion:
#
# Based on the evaluation of MSE, RMSE, and R², **Model 1 (likely a Random Forest or Gradient Boosting Regressor)** is classified as the best performing model for predicting movie ratings. It demonstrates lower prediction errors (MSE, RMSE) and better ability to explain variance in ratings (R²) compared to the SVR model and potentially Model 2. This classification suggests that Model 1 is likely to provide more accurate and reliable predictions for movie ratings based on the given features.
#
# When implementing such a model in practice, it would be beneficial to further validate its performance on unseen data and potentially perform additional optimizations such as hyperparameter tuning to further enhance its predictive power.

# %% [markdown]
# Based on the analysis of Model 1's performance metrics:
#
# - **Model 1**: This refers to a regression model (likely RandomForestRegressor or GradientBoostingRegressor) that was evaluated based on the provided metrics:
#
#   - **Mean Squared Error (MSE)**: 0.01
#   - **Root Mean Squared Error (RMSE)**: 0.10
#   - **R-squared (R²)**: 0.20
#
# These metrics suggest the following interpretations regarding how Model 1 predicts the rating of a movie based on features like genre, director, and actors:
#
# 1. **Accuracy of Predictions**:
#    - **MSE**: The average squared difference between predicted and actual ratings is very low (0.01), indicating that on average, the predictions are very close to the actual ratings.
#    - **RMSE**: The RMSE of 0.10 means that, on average, the predictions deviate by 0.10 units from the actual ratings. This is a small margin of error, indicating precise predictions.
#    - **R-squared (R²)**: The R² value of 0.20 indicates that approximately 20% of the variance in movie ratings can be explained by the features used in the model. This suggests that the selected features (genre, director, actors) collectively have a moderate explanatory power in predicting movie ratings.
#
# 2. **Feature Importance**:
#    - Models like RandomForestRegressor and GradientBoostingRegressor provide insights into feature importance. The higher the feature's importance, the more influence it has on predicting the movie rating. Features like genre (e.g., action, drama), director (e.g., famous or experienced directors), and actors (e.g., popular or talented actors) are likely to be among the most important features influencing the predicted movie ratings.
#
# 3. **Model Reliability**:
#    - Given the low MSE, low RMSE, and reasonably high R², Model 1 is likely to be reliable in predicting movie ratings based on the provided features. It suggests that these features capture significant aspects of what makes a movie popular or well-received in terms of ratings.
#
# 4. **Generalization**:
#    - It's crucial to ensure that Model 1 generalizes well to unseen data. This involves validating its performance on a separate test set to confirm that it maintains its predictive accuracy and explanatory power beyond the training data.
#
# ### Conclusion:
#
# Model 1 indicates that it can effectively predict the rating of a movie based on features like genre, director, and actors with high precision (low MSE and RMSE) and moderate explanatory power (R² of 0.20). This suggests that these features play a meaningful role in determining how a movie is rated, making the model valuable for predicting and understanding movie ratings based on these key attributes.
